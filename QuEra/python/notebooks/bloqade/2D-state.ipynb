# %% [markdown]
# 2D State Preparation
# In this example we show how to create the Striated Phase on a 2D chain of atoms

# %%
from bloqade.atom_arrangement import Square
from bloqade import save, load
from bokeh.io import output_notebook

# This tells Bokeh to display output in the notebook
# versus opening a browser window
output_notebook()
! pip3 list |grep bloq
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e55b79e1-fcf5-491f-b70f-7e8e53ad67d0">Loading BokehJS ...</span>
#     </div>
# bloqade                           0.15.14

# %%
# Have atoms separated by 5.9 micrometers
L = 3
lattice_spacing = 6.5

rabi_amplitude_values = [0.0, 15.8, 15.8, 0.0]
rabi_detuning_values = [-16.33, -16.33, "delta_end", "delta_end"]
durations = [0.8, "sweep_time", 0.8]

prog = (
    Square(L, lattice_spacing=lattice_spacing)
    .rydberg.rabi.amplitude.uniform.piecewise_linear(durations, rabi_amplitude_values)
    .detuning.uniform.piecewise_linear(durations, rabi_detuning_values)
)

batch = prog.assign(delta_end=42.66, sweep_time=2.4)

# %%
emu_batch = batch.braket.local_emulator().run(shots=30)

# %%
report = emu_batch.report()
counts=report.counts()   # does it remove 'e' from pre-measure and is '1'=rydberg?
print('Counts:',counts)
# Out:
# Counts: [OrderedDict({'010101010': 29, '010111010': 1})]

# %%
report.show()
# Out:
# 0.0 13.0 0.0 13.0
#   <div id="a34ccd5f-a0ee-4d62-ab9b-0ef0090fc258" data-root-id="p1639" style="display: contents;"></div>

# %%
emu_batch.source.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 emu_batch.source.show()
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/builder/parse/trait.py:196, in Show.show(self, batch_id, *args)
#     174 def show(self, *args, batch_id: int = 0):
#     175     """
#     176     Display the current program being defined with the given arguments and batch ID.
#     177
#    (...)
#     194     ```
#     195     """
# --> 196     display_builder(self, batch_id, *args)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/display.py:91, in display_builder(builder, batch_id, *args)
#      90 def display_builder(builder, batch_id, *args):
# ---> 91     fig = builder_figure(builder, batch_id, *args)
#      92     show(fig)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/display.py:84, in builder_figure(builder, batch_id, *args)
#      81 for key, val in kwargs.items():
#      82     out += liner(f" :: {key} = {val}")
# ---> 84 field, reg = analog_circ.figure(**kwargs)
#      86 div = Div(text=out, width=200, height=200)
#      87 return row(field, column(reg, div))
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/ir/analog_circuit.py:75, in AnalogCircuit.figure(self, **assignments)
#      72 fig_keys = []
#      74 fig_reg = self.register.figure(**assignments)
# ---> 75 fig_seq = self.sequence.figure(**assignments)
#      77 fig_regs.append(fig_reg)
#      78 fig_keys.append("Filling")
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/ir/control/sequence.py:165, in Sequence.figure(self, **assignments)
#     164 def figure(self, **assignments):
# --> 165     return get_ir_figure(self, **assignments)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/ir_visualize.py:380, in get_ir_figure(ir, **assignments)
#     377 from bloqade.ir.control.waveform import Waveform
#     379 if isinstance(ir, SequenceExpr):
# --> 380     return get_sequence_figure(ir, **assignments)
#     381 elif isinstance(ir, SpatialModulation):
#     382     return get_spmod_figure(ir, **assignments)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/ir_visualize.py:362, in get_sequence_figure(ir_seq, **assignments)
#     360 for lvl, pulse in pulses.items():
#     361     if seq_name is None:
# --> 362         p = get_pulse_panel(pulse, title=str(lvl), **assignments)
#     363     else:
#     364         p = get_pulse_panel(pulse, title=str(lvl) + f"({seq_name})", **assignments)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/ir_visualize.py:346, in get_pulse_panel(ir_pulse, title, **assignments)
#     344 pulse_figs = []
#     345 for Field_name, field in fields.items():
# --> 346     p = get_field_figure(field, str(Field_name), shared_indicator, **assignments)
#     347     pulse_figs.append(p)
#     348 p_all = assemble_pulse_panel(pulse_figs, pulse_name)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/ir_visualize.py:317, in get_field_figure(ir_field, title, indicator, **assignments)
#     316 def get_field_figure(ir_field, title, indicator, **assignments):
# --> 317     dats, names, spinfo = format_field_data(ir_field, **assignments)
#     318     if indicator is None:
#     319         fig = Field_wvfm(
#     320             colors=itertools.cycle(Dark2_5), data_sources=dats, ch_names=names
#     321         )
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/visualization/ir_visualize.py:271, in format_field_data(field_ir, **assignments)
#     268 locs, scales = spmod_ir._get_data(**assignments)
#     270 ## deal with wvfm:
# --> 271 times, values = wvfm_ir._get_data(1000, **assignments)
#     273 if str(spmod_ir) == "Uniform":
#     274     name = "Uni[%d]" % (len(ch_names["uni"]))
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/ir/control/waveform.py:111, in Waveform._get_data(self, npoints, **assignments)
#     107 from bloqade.compiler.analysis.common.assignment_scan import AssignmentScan
#     109 assignments = AssignmentScan(assignments).scan(self)
# --> 111 duration = float(self.duration(**assignments))
#     112 times = np.linspace(0, duration, npoints + 1)
#     113 values = [self.__call__(time, **assignments) for time in times]
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/ir/scalar.py:509, in Add.__call__(self, **assignments)
#     508 def __call__(self, **assignments) -> Decimal:
# --> 509     return self.lhs(**assignments) + self.rhs(**assignments)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/ir/scalar.py:509, in Add.__call__(self, **assignments)
#     508 def __call__(self, **assignments) -> Decimal:
# --> 509     return self.lhs(**assignments) + self.rhs(**assignments)
#
# File /opt/venv/lib/python3.12/site-packages/bloqade/ir/scalar.py:311, in Variable.__call__(self, **assignments)
#     309 def __call__(self, **assignments) -> Decimal:
#     310     if self.name not in assignments:
# --> 311         raise ValueError(f"Variable {self.name} not assigned")
#     313     return Decimal(str(assignments[self.name]))
#
# ValueError: Variable sweep_time not assigned
